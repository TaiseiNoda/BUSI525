# %% [markdown]
# ## BUSI 525 Problem Set #3
# **Finite Sample Bias in Predictive Regressions**

# %% [markdown]
# **Taisei Noda**
# [GitHub Link](https://github.com/TaiseiNoda/BUSI525)

# %%
using Plots, Random, Statistics, Bootstrap, Distributions, LinearAlgebra,StatsBase

function Stambaugh(T,rho_uv;B=250,alpha=0.0,beta=0.015,sigma_u=0.053,theta=0,sigma_v=0.044,rho=0.98)
    d1 = MvNormal(zeros(2),[sigma_u^2. rho_uv*sigma_u*sigma_v;rho_uv*sigma_u*sigma_v sigma_v^2])
    est_beta = zeros(B)
    for b = 1:B
        uv = rand(d1, T)
        u = uv[1,:]
        v = uv[2,:]
        x = zeros(T)
        r = zeros(T)
        for t = 1:T
            if t == 1
                x[t] = theta + rho*0.0 + v[t]
                r[t] = alpha + beta*0.0 + u[t]
            else
            x[t] = theta + rho*x[t-1] + v[t]
            r[t] = alpha + beta*x[t-1] + u[t]
            end
        end
        X = hcat(ones(T),x)
        estimator = (X'X)\(X'r)
        est_beta[b] = estimator[2]
    end
    beta_percentiles = [percentile(est_beta, 5),mean(est_beta),percentile(est_beta,95)]
    return beta_percentiles
end
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1317
# Stambaugh (generic function with 1 method)

# %% [markdown]
# ### Part 1: Finite Sample Bias

# %%
Ts = 120:120:1200
beta_plots = zeros(length(Ts),3)
for i=1:length(Ts)
    beta_plots[i,:]=Stambaugh(Ts[i],-0.8)
end
plotlyjs();
p1 = plot(xlabel="T",ylabel="Est. Beta",legend=:bottomright)
p1 = plot!(Ts,beta_plots[:,1],label = "5% percentile")
p1 = plot!(Ts,beta_plots[:,2],label = "Mean")
p1 = plot!(Ts,beta_plots[:,3],label = "95% percentile")
# Out:
#     <div id="e3969102-a71f-43d1-8cf0-350e2822b10b" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('e3969102-a71f-43d1-8cf0-350e2822b10b');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             120,
#             240,
#             360,
#             480,
#             600,
#             720,
#             840,
#             960,
#             1080,
#             1200
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "5% percentile",
#         "zmin": null,
#         "legendgroup": "5% percentile",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -0.1446777195995861,
#             -0.09305779233102014,
#             -0.06935010493485264,
#             -0.06444727295230458,
#             -0.053657008489772166,
#             -0.050786956134554376,
#             -0.04842169723523919,
#             -0.04614052573859254,
#             -0.04433996407669577,
#             -0.043302307379337684
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             120,
#             240,
#             360,
#             480,
#             600,
#             720,
#             840,
#             960,
#             1080,
#             1200
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Mean",
#         "zmin": null,
#         "legendgroup": "Mean",
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -0.06881660422012269,
#             -0.046164679706300386,
#             -0.036447417873854256,
#             -0.033085681437641484,
#             -0.03265375038594092,
#             -0.0312801571594141,
#             -0.029342194284360957,
#             -0.028820454390171463,
#             -0.028117499993166185,
#             -0.028087561407394886
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             120,
#             240,
#             360,
#             480,
#             600,
#             720,
#             840,
#             960,
#             1080,
#             1200
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "95% percentile",
#         "zmin": null,
#         "legendgroup": "95% percentile",
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -0.016532835103240454,
#             -0.01304369499999809,
#             -0.012096196491797934,
#             -0.013324096927599704,
#             -0.016460504958700693,
#             -0.016505138238627783,
#             -0.014263924015171174,
#             -0.01686041430570723,
#             -0.01761279639476592,
#             -0.01718003145135347
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             250.0,
#             500.0,
#             750.0,
#             1000.0
#         ],
#         "range": [
#             87.6,
#             1232.4
#         ],
#         "domain": [
#             0.1209135316418781,
#             0.9934383202099738
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "250",
#             "500",
#             "750",
#             "1000"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "T",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             -0.125,
#             -0.1,
#             -0.07500000000000001,
#             -0.05,
#             -0.025
#         ],
#         "range": [
#             -0.14865516529281975,
#             -0.008118750798564289
#         ],
#         "domain": [
#             0.07581474190726165,
#             0.9901574803149606
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "-0.125",
#             "-0.100",
#             "-0.075",
#             "-0.050",
#             "-0.025"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "Est. Beta",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "bottom",
#         "xanchor": "right",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 0.07,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>

# %% [markdown]
# The larger T becomes, the smaller bias is in absolute sence. The 95 percentile of the biases approaches to zero. However, the gain is not significant if we have more than 1000 observations and the estimator has negative bias.

# %% [markdown]
# ### Part 2 - Effect of residual correlation

# %%
rho_uvs = [-0.2,-0.5,-0.8]
beta_plots_corr = zeros(length(Ts),length(rho_uvs))
for j = 1:length(rho_uvs)
    for i=1:length(Ts)
        beta_plots_corr[i,j]=Stambaugh(Ts[i],rho_uvs[j])[2]
    end
end

p2 = plot(xlabel="T",ylabel="Est. Beta",legend=:bottomright)
p2 = plot!(Ts,beta_plots_corr[:,1],label = "corr = -0.2")
p2 = plot!(Ts,beta_plots_corr[:,2],label = "corr = -0.5")
p2 = plot!(Ts,beta_plots_corr[:,3],label = "corr = -0.8")
# Out:
#     <div id="b11e65b0-26d8-4101-a304-ff410263bfa9" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('b11e65b0-26d8-4101-a304-ff410263bfa9');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             120,
#             240,
#             360,
#             480,
#             600,
#             720,
#             840,
#             960,
#             1080,
#             1200
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "corr = -0.2",
#         "zmin": null,
#         "legendgroup": "corr = -0.2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -0.00990665473571667,
#             -0.000834908038647794,
#             0.0022087550755244476,
#             0.0028609793937475893,
#             0.003847092274068109,
#             0.0029913457466290935,
#             0.0029337694245223306,
#             0.003824626412967388,
#             0.004566597175354234,
#             0.004044681585921059
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             120,
#             240,
#             360,
#             480,
#             600,
#             720,
#             840,
#             960,
#             1080,
#             1200
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "corr = -0.5",
#         "zmin": null,
#         "legendgroup": "corr = -0.5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -0.043096105328439195,
#             -0.024301336273536863,
#             -0.017901144237961047,
#             -0.016022503430886036,
#             -0.014124077793437707,
#             -0.01438175695684166,
#             -0.013174871324479932,
#             -0.013469284498428855,
#             -0.012539353475469403,
#             -0.011420089101929022
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             120,
#             240,
#             360,
#             480,
#             600,
#             720,
#             840,
#             960,
#             1080,
#             1200
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "corr = -0.8",
#         "zmin": null,
#         "legendgroup": "corr = -0.8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -0.06739299112810458,
#             -0.04763223732426742,
#             -0.039664393757502914,
#             -0.033865112203504466,
#             -0.03179882814667019,
#             -0.031227446923195682,
#             -0.029761474149978307,
#             -0.029409657130045203,
#             -0.02854423330300623,
#             -0.026878485400655672
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             250.0,
#             500.0,
#             750.0,
#             1000.0
#         ],
#         "range": [
#             87.6,
#             1232.4
#         ],
#         "domain": [
#             0.10609871682706327,
#             0.9934383202099737
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "250",
#             "500",
#             "750",
#             "1000"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "T",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             -0.06,
#             -0.05,
#             -0.04,
#             -0.03,
#             -0.02,
#             -0.01,
#             0.0
#         ],
#         "range": [
#             -0.06955177877720835,
#             0.0067253848244579984
#         ],
#         "domain": [
#             0.07581474190726165,
#             0.9901574803149606
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "-0.06",
#             "-0.05",
#             "-0.04",
#             "-0.03",
#             "-0.02",
#             "-0.01",
#             "0.00"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "Est. Beta",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "bottom",
#         "xanchor": "right",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 0.07,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>

# %% [markdown]
# As the corrleation between the errors becomes stronger, the estimates have larger negative bias. Larger sample size mitigates the bias.
